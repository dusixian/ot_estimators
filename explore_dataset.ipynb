# %%
import numpy as np

# 加载.npy文件
dataset = np.load('20news/dataset.npy', allow_pickle=True)
queries = np.load('20news/queries.npy', allow_pickle=True)
vocab = np.load('20news/vocab.npy', allow_pickle=True)
answers = np.load('20news/answers.npy', allow_pickle=True)

# 打印基本信息
print("=== dataset.npy ===")
print("Shape:", dataset.shape)
print("Data type:", dataset.dtype)
print("First few elements:", dataset[:2])
print(len(dataset[0]), len(dataset[1]))

print("\n=== queries.npy ===")
print("Shape:", queries.shape)
print("Data type:", queries.dtype)
print("First few elements:", queries[:2])
print(len(queries[0]), len(queries[1]))

print("\n=== vocab.npy ===")
print("Shape:", vocab.shape)
print("Data type:", vocab.dtype)
print("First few elements:", vocab[:2])

print("\n=== answers.npy ===")
print("Shape:", answers.shape)
print("Data type:", answers.dtype)
print("First few elements:", answers[:2])
# Out:
# === dataset.npy ===
# Shape: (11314,)
# Data type: object
# First few elements: [list([342244, 1698, 569, 734, 221, 3589, 499, 625, 1330, 9215, 57269, 569, 122, 1888, 884, 569, 1803, 288, 175, 112798, 3898, 1072, 669, 14228, 1350, 1033, 719, 153026, 1423, 311, 2100, 53753, 618, 569, 299, 2684, 14035, 21727, 862, 569, 3832, 12243, 3124, 6119, 845, 2401])
#  list([1856, 20107, 1698, 13386, 4974, 1887, 294, 580, 4414, 294, 580, 13386, 4974, 687, 44333, 734, 221, 289, 1330, 1791, 9147, 11713, 8570, 13386, 4974, 45470, 2719, 5035, 1887, 3832, 1545, 2461, 1443, 13106, 5035, 4753, 220, 1512, 13548, 23054, 4098, 1512, 1679, 2927, 50114, 1965, 18386, 1152, 7379, 122, 23070, 8118, 18792, 97644, 858, 4095, 41850, 249, 3832, 1679, 849, 2489, 815, 4974, 6837, 201398, 5966, 1887, 3124, 1856, 20107])]
# 46 71
#
# === queries.npy ===
# Shape: (1000,)
# Data type: object
# ...
